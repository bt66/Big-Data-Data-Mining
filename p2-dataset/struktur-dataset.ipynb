# %%
list1 = ['Bigdata & Data Mining', 'BigData & Predictive Analytic', 2022, 2022]
list2 = ['buku', 'pensil', 'penggaris', 'spidol', 'bolpoin', 'penghapus']
list3 = ['a', 'b', 'c', 'd']

# %%
print("list1[0]: ", list1[0])
print("list2[1:5]: ", list2[1:5])
# Out:
# list1[0]:  Bigdata & Data Mining
# list2[1:5]:  ['pensil', 'penggaris', 'spidol', 'bolpoin']

# %%
print("list2[2:4]:", list3[2:4])
# Out:
# list2[2:4]: ['c', 'd']

# %%
print(list2[1], ' ', list2[2])
print(list2[1:3])
# Out:
# pensil   penggaris
# ['pensil', 'penggaris']

# %% [markdown]
# dataframe

# %%
import pandas as pd

data = {
    'buah': ['apel', 'pisang', 'jeruk', 'nanas', 'durian'],
    'sayur': ['bayam', 'sawi', 'wortel', 'kentang', 'kacang'],
    'hewan': ['kucing', 'kambing', 'sapi', 'kelinci', 'buaya']
}

df = pd.DataFrame(data)
df.head()
# Out:
#      buah    sayur    hewan
# 0    apel    bayam   kucing
# 1  pisang     sawi  kambing
# 2   jeruk   wortel     sapi
# 3   nanas  kentang  kelinci
# 4  durian   kacang    buaya

# %%
print(data['hewan'][2])
# Out:
# sapi

# %%
print(data['sayur'][3], " ", data['hewan'][4])
# Out:
# kentang   buaya

# %% [markdown]
# tuple

# %%
tup1 = ('Bigdata & Data Mining', 'BigData & Predictive Analytic', 2022, 2022)
tup2 = (1, 2, 3, 4, 5)
tup3 = ('a', 'b', 'c', 'd')

# %%
type (tup1)
# Out:
# tuple

# %%
type (list1)
# Out:
# list

# %%
len(tup2)
# Out:
# 5

# %%
print("tup1[0]:", tup1[0])
print("tup2[1:5]:", tup1[1:5])
# Out:
# tup1[0]: Bigdata & Data Mining
# tup2[1:5]: ('BigData & Predictive Analytic', 2022, 2022)

# %%
print(tup2, ' & ', tup3)
print(tup2+tup3)
# Out:
# (1, 2, 3, 4, 5)  &  ('a', 'b', 'c', 'd')
# (1, 2, 3, 4, 5, 'a', 'b', 'c', 'd')

# %%
print(*tup2)
# Out:
# 1 2 3 4 5

# %%
print(type(tup1))
print(type(tup2))
print(type(tup3))
# Out:
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>

# %%
tup_nim = (3,7,1,4)
print(tup_nim)
# Out:
# (3, 7, 1, 4)

# %% [markdown]
# dictionary berisi key dan value

# %%
dict = {'Name': 'Zara', 'Age': 20, 'Class': 'BigData1'}

print("dict['Name']: ", dict['Name'])
print("dict['Age]: ", dict['Age'])

print(dict)
# Out:
# dict['Name']:  Zara
# dict['Age]:  20
# {'Name': 'Zara', 'Age': 20, 'Class': 'BigData1'}

# %%
# update dictionary
dict['Age']= 10
print(dict)
# Out:
# {'Name': 'Zara', 'Age': 10, 'Class': 'BigData1'}

# %%
dict = [dict, {'Nama':'Zr','Age':11,'Class':'BigData0'}]
dict = [{'Nama':'Zara','Age':20,'Class':'BigData1'},{'Nama':'Zr','Age':11,'Class':'BigData0'}]
print(dict)
# Out:
# [{'Nama': 'Zara', 'Age': 20, 'Class': 'BigData1'}, {'Nama': 'Zr', 'Age': 11, 'Class': 'BigData0'}]

# %%
data = [{'Nama':'Zara','Age':20,'Class':'BigData1'},
        {'Nama':'Zr','Age':15,'Class':'BigData2'},
        {'Nama':'AR','Age':16,'Class':'BigData3'}]
df = pd.DataFrame(data)
df.head()
# Out:
#    Nama  Age     Class
# 0  Zara   20  BigData1
# 1    Zr   15  BigData2
# 2    AR   16  BigData3

# %%
df = pd.read_csv('/content/sample_data/california_housing_test.csv')
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %%
df.head(15)
# Out:
#     longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0     -122.05     37.37                27.0       3885.0           661.0
# 1     -118.30     34.26                43.0       1510.0           310.0
# 2     -117.81     33.78                27.0       3589.0           507.0
# 3     -118.36     33.82                28.0         67.0            15.0
# 4     -119.67     36.33                19.0       1241.0           244.0
# 5     -119.56     36.51                37.0       1018.0           213.0
# 6     -121.43     38.63                43.0       1009.0           225.0
# 7     -120.65     35.48                19.0       2310.0           471.0
# 8     -122.84     38.40                15.0       3080.0           617.0
# 9     -118.02     34.08                31.0       2402.0           632.0
# 10    -118.24     33.98                45.0        972.0           249.0
# 11    -119.12     35.85                37.0        736.0           166.0
# 12    -121.93     37.25                36.0       1089.0           182.0
# 13    -117.03     32.97                16.0       3936.0           694.0
# 14    -117.97     33.73                27.0       2097.0           325.0
#
#     population  households  median_income  median_house_value
# 0       1537.0       606.0         6.6085            344700.0
# 1        809.0       277.0         3.5990            176500.0
# 2       1484.0       495.0         5.7934            270500.0
# 3         49.0        11.0         6.1359            330000.0
# 4        850.0       237.0         2.9375             81700.0
# 5        663.0       204.0         1.6635             67000.0
# 6        604.0       218.0         1.6641             67000.0
# 7       1341.0       441.0         3.2250            166900.0
# 8       1446.0       599.0         3.6696            194400.0
# 9       2830.0       603.0         2.3333            164200.0
# 10      1288.0       261.0         2.2054            125000.0
# 11       564.0       138.0         2.4167             58300.0
# 12       535.0       170.0         4.6900            252600.0
# 13      1935.0       659.0         4.5625            231200.0
# 14      1217.0       331.0         5.7121            222500.0

# %%
df.loc[1:5]
df.loc[1:5, ['longitude','longitude', 'housing_median_age']]
# Out:
#    longitude  longitude  housing_median_age
# 1    -118.30    -118.30                43.0
# 2    -117.81    -117.81                27.0
# 3    -118.36    -118.36                28.0
# 4    -119.67    -119.67                19.0
# 5    -119.56    -119.56                37.0
