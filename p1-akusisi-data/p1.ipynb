# %% [markdown]
# **COLLECTING DATA**

# %%
import pandas as pd

# %%
url="https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data"

df=pd.read_csv(url)

# %%
df.head()
# Out:
#    5.1  3.5  1.4  0.2  Iris-setosa
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa

# %%
column_header=["sepal_length","sepal_width","petal_length","petal_width","class"]
df.columns=column_header
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width        class
# 0           4.9          3.0           1.4          0.2  Iris-setosa
# 1           4.7          3.2           1.3          0.2  Iris-setosa
# 2           4.6          3.1           1.5          0.2  Iris-setosa
# 3           5.0          3.6           1.4          0.2  Iris-setosa
# 4           5.4          3.9           1.7          0.4  Iris-setosa

# %% [markdown]
# download dataset

# %%
from google.colab import files
df.to_csv("data-iris.csv", index=False)
files.download('data-iris.csv')

# %% [markdown]
# save dataset to google drive

# %%
from google.colab import drive
drive.mount('/content ',force_remount=True)
path = '/content/drive/MyDrive/kuliah/Smester 5/'
df.to_csv(path+'Data-Iris.csv', index=False)
# Out:
# Mounted at /content/drive

# %%
data = pd.read_csv('/content/drive/MyDrive/kuliah/Smester 5/archive.zip')
data.head()
# Out:
#    Unnamed: 0  work_year experience_level employment_type  \
# 0           0       2020               MI              FT
# 1           1       2020               SE              FT
# 2           2       2020               SE              FT
# 3           3       2020               MI              FT
# 4           4       2020               SE              FT
#
#                     job_title  salary salary_currency  salary_in_usd  \
# 0              Data Scientist   70000             EUR          79833
# 1  Machine Learning Scientist  260000             USD         260000
# 2           Big Data Engineer   85000             GBP         109024
# 3        Product Data Analyst   20000             USD          20000
# 4   Machine Learning Engineer  150000             USD         150000
#
#   employee_residence  remote_ratio company_location company_size
# 0                 DE             0               DE            L
# 1                 JP             0               JP            S
# ...

# %% [markdown]
# read from GD

# %%
url = 'https://drive.google.com/file/d/1O58Qjw7GAL9O1PxRCzIJyDs0DYiejpqO/view?usp=sharing'
id_file = url.split('/')[-2]
print(id_file)
baseurl = 'https://drive.google.com/uc?id=' + id_file
dataset = pd.read_csv(baseurl)
dataset.head()
# Out:
# 1O58Qjw7GAL9O1PxRCzIJyDs0DYiejpqO
#    Unnamed: 0  work_year experience_level employment_type  \
# 0           0       2020               MI              FT
# 1           1       2020               SE              FT
# 2           2       2020               SE              FT
# 3           3       2020               MI              FT
# 4           4       2020               SE              FT
#
#                     job_title  salary salary_currency  salary_in_usd  \
# 0              Data Scientist   70000             EUR          79833
# 1  Machine Learning Scientist  260000             USD         260000
# 2           Big Data Engineer   85000             GBP         109024
# 3        Product Data Analyst   20000             USD          20000
# 4   Machine Learning Engineer  150000             USD         150000
#
#   employee_residence  remote_ratio company_location company_size
# 0                 DE             0               DE            L
# ...

# %%
! pip install -q kaggle
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-35306af2-09fe-4999-90ea-f37a0ede3839" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-35306af2-09fe-4999-90ea-f37a0ede3839">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
! mkdir ~/.kaggle
! cp kaggle.json ~/.kaggle/

# %%
! ls ~/.kaggle
# Out:
# kaggle.json

# %%
! chmod 600 ~/.kaggle/kaggle.json

# %%
! kaggle datasets list
# Out:
# ref                                                            title                                                size  lastUpdated          downloadCount  voteCount  usabilityRating
# -------------------------------------------------------------  --------------------------------------------------  -----  -------------------  -------------  ---------  ---------------
# iamsouravbanerjee/world-population-dataset                     World Population Dataset                             17KB  2022-08-31 11:20:04          10802        325  1.0
# pantanjali/unemployment-dataset                                Unemployment dataset                                 17KB  2022-09-08 08:26:10           2970         82  1.0
# harshsingh2209/tesla-stock-pricing-20172022                    TESLA stock pricing (2017-2022)                      28KB  2022-09-18 14:56:29            508         23  1.0
# ...

# %%
# !kaggle datasets download -d iamsouravbanerjee/world-population-dataset
# Out:
# ...
#   0% 0.00/17.1k [00:00<?, ?B/s]
# 100% 17.1k/17.1k [00:00<00:00, 21.1MB/s]

# %%
# !ls
# Out:
#  data-iris.csv	 gdrive		    kaggle.json   world-population-dataset.zip
#  drive		'kaggle (1).json'   sample_data

# %%
import zipfile
zip = zipfile.ZipFile('world-population-dataset.zip', 'r')
zip.extractall('files')
zip.close()

# %%
# !ls
# Out:
#  data-iris.csv	 files	 'kaggle (1).json'   sample_data
#  drive		 gdrive   kaggle.json	     world-population-dataset.zip
