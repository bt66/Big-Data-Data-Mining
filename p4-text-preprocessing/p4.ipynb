# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/content/drive/MyDrive/kuliah/Smester 5/big data & data mining/p5/ReviewHotel50.csv")
df.head()
# Out:
#                                               review  service
# 0  Saya kehilangan barang saya yang kelupaan di k...        0
# 1  Hotel ini terletak di daerah terpencil di jala...        0
# 2  Check innya lama banget kamar belum siap katan...        0
# 3  Ini kedua kalinya keluarga saya menginap di vi...        1
# 4  Saya pilih kamar yang ternyata kamar mandinya ...        1

# %% [markdown]
# text folding
#
# di gunakan untuk mengubah semua text menjadi uppercase atau lowercase

# %%
kalimat = "Indonesia itu indeh, terdapat pulau besar seperti Jawa, Kalimantan, Sumatera";
lower_case = kalimat.lower()
print(lower_case)
# Out:
# indonesia itu indeh, terdapat pulau besar seperti jawa, kalimantan, sumatera

# %% [markdown]
# Data Cleaning

# %%
import re
# replace string 
txt = 'Hi! @Mukidi, apa kabar? #sapa pagi.'
print(re.sub(r'[^\w]', ' ', txt))
# atau jika ingin exclude titik dan koma 
# re.sub(r'[^.,a-zA-Z0-9] \n\.]', '', txt)
# Out:
# Hi   Mukidi  apa kabar   sapa pagi

# %%
#test 

result = re.sub(pattern, '',phone_no)

# %%
tweet = '#AmdaiSajaTahu #ApaYangAkuRasah... #AlayersTweet #d2d'

getHastags = re.compile(r"#(\w+)")
print("Tags = {0}".format(re.findall(getHastags, tweet)))
# Out:
# Tags = ['AmdaiSajaTahu', 'ApaYangAkuRasah', 'AlayersTweet', 'd2d']

# %%
# Extracting atau replacing eMail.
emailPattern = re.compile(r'[\w._%+-]+@[\w\.-]+\.[a-zA-Z]{2,4}')
txt = 'Contact kami di sdb@gmail.com, test.satu@gmail.com atau sdsd@asdf.com jangan lewat asdf.com karena itu bukan email';
print(re.sub(emailPattern, ' ', txt))
emails = re.findall(emailPattern, txt)
print("Email yang di temukan", str(emails))
# Out:
# re.compile('[\\w._%+-]+@[\\w\\.-]+\\.[a-zA-Z]{2,4}')
# Contact kami di  ,   atau   jangan lewat asdf.com karena itu bukan email
# Email yang di temukan ['sdb@gmail.com', 'test.satu@gmail.com', 'sdsd@asdf.com']

# %%
kalimat = "terdapat 5 jenis 4 ikan di 5 kolam itu, lele, gurami, nila, patin. mas"
hasil = re.sub(r"\d+", "", kalimat)
test = re.findall(r'[0-9]+', kalimat)
print(hasil)
print(test)
x = np.array(test)
x.astype(np.float)
# Out:
# terdapat  jenis  ikan di  kolam itu, lele, gurami, nila, patin. mas
# ['5', '4', '5']
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   import sys
# array([5., 4., 5.])

# %%
urlPattern = re.compile(r'http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+')

txt = "website reguler expression & my site : https://www.regular.expression/info/ & https://tau-data.id"
print(re.sub(urlPattern, " ", txt))
URLs = re.findall(urlPattern, txt)
print("Url yanng di temukan: ", str(URLs))
# Out:
# website reguler expression & my site :   &
# Url yanng di temukan:  ['https://www.regular.expression/info/', 'https://tau-data.id']

# %% [markdown]
# Tokenizing adalah proses pemisahan text menjadi potongan yang di sebut sebagai token untuk kemudian di analisa. kata, angka, simbol, tanda baca dan entitas penting lainnya dapat di anggap sebagai token. dalam NLP, token di artikan sebagai kata

# %%
# !pip install nltk
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
from nltk.tokenize import word_tokenize

kalimat = "Kita sedang belajar Data Mining, materi pre-processing"

tokens = nltk.tokenize.word_tokenize(kalimat)
print(tokens)
# Out:
# ['Kita', 'sedang', 'belajar', 'Data', 'Mining', ',', 'materi', 'pre-processing']

# %%
from nltk.probability import FreqDist

kalimat = '''Lala sering sekali berbelanja online terutama pada saat pandemi. MEnurut lala 
belanja online lebih praktis daripada belanja di pasar.'''

tokens = nltk.tokenize.word_tokenize(kalimat)
kemunculan = nltk.FreqDist(tokens)
print(kemunculan.most_common())

#tokens_Lower = nltk.tokenize.word_tokenize(kalimat.lower())
#kemunculan_lower = nltk.FreqDist(tokens)
#print(kemunculan_lower.most_common())
# Out:
# [('online', 2), ('.', 2), ('belanja', 2), ('Lala', 1), ('sering', 1), ('sekali', 1), ('berbelanja', 1), ('terutama', 1), ('pada', 1), ('saat', 1), ('pandemi', 1), ('MEnurut', 1), ('lala', 1), ('lebih', 1), ('praktis', 1), ('daripada', 1), ('di', 1), ('pasar', 1)]
# [('online', 2), ('.', 2), ('belanja', 2), ('Lala', 1), ('sering', 1), ('sekali', 1), ('berbelanja', 1), ('terutama', 1), ('pada', 1), ('saat', 1), ('pandemi', 1), ('MEnurut', 1), ('lala', 1), ('lebih', 1), ('praktis', 1), ('daripada', 1), ('di', 1), ('pasar', 1)]

# %%
from nltk.tokenize import sent_tokenize

kalimat = '''kita sedang belajar data mining, materi pre-processing sub materi tokenizing. menyenangkan bukan'''

tokens = nltk.tokenize.sent_tokenize(kalimat)
print(tokens)
# Out:
# ['kita sedang belajar data mining, materi pre-processing sub materi tokenizing.', 'menyenangkan bukan']

# %% [markdown]
# Filtering
#
# di gunakan untuk menghapus kata hubung

# %%
from nltk.corpus import stopwords

kalimat = '''Lala sering sekali berbelanja online terutama pada saat pandemi. MEnurut lala 
belanja online lebih praktis daripada belanja di pasar.'''

tokens = word_tokenize(kalimat)
listStopword = set(stopwords.words('indonesian'))

removed = []
for t in tokens:
  if t not in listStopword:
    removed.append(t)

print(removed)
# Out:
# ['Lala', 'berbelanja', 'online', 'pandemi', '.', 'MEnurut', 'lala', 'belanja', 'online', 'praktis', 'belanja', 'pasar', '.']

# %% [markdown]
# stemming
#
# proses pemetaan dan penguraian bentuk dari suatu kate menjadi kata dasarnya

# %%
# !pip install Sastrawi
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 209 kB 4.9 MB/s
# ...

# %%
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
factory = StemmerFactory()
stemmer = factory.create_stemmer()
